# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# 1. load data set using pandas function and print first 5 records.

data = pd.read_csv("cars.csv")
data
# Out:
#      Unnamed: 0  price      brand    model  year   title_status  mileage  \
# 0             0   6300     toyota  cruiser  2008  clean vehicle   274117
# 1             1   2899       ford       se  2011  clean vehicle   190552
# 2             2   5350      dodge      mpv  2018  clean vehicle    39590
# 3             3  25000       ford     door  2014  clean vehicle    64146
# 4             4  27700  chevrolet     1500  2018  clean vehicle     6654
# ..          ...    ...        ...      ...   ...            ...      ...
# 172         172   5470      dodge      mpv  2018  clean vehicle    39721
# 173         173  14600       ford     door  2014  clean vehicle    75785
# 174         174  24502  chevrolet     1500  2016  clean vehicle    33624
# 175         175  15110       ford     door  2017  clean vehicle    42289
# 176         176   7900       ford     door  2014  clean vehicle    79422
#
#       color                  vin        lot         state country  \
# ...

# %%
data.head(5)
# Out:
#    Unnamed: 0  price      brand    model  year   title_status  mileage  \
# 0           0   6300     toyota  cruiser  2008  clean vehicle   274117
# 1           1   2899       ford       se  2011  clean vehicle   190552
# 2           2   5350      dodge      mpv  2018  clean vehicle    39590
# 3           3  25000       ford     door  2014  clean vehicle    64146
# 4           4  27700  chevrolet     1500  2018  clean vehicle     6654
#
#     color                  vin        lot       state country      condition
# 0   black    jtezu11f88k007763  159348797  new jersey     usa   10 days left
# 1  silver    2fmdk3gc4bbb02217  166951262   tennessee     usa    6 days left
# 2  silver    3c4pdcgg5jt346413  167655728     georgia     usa    2 days left
# 3    blue    1ftfw1et4efc23745  167753855    virginia     usa  22 hours left
# 4     red    3gcpcrec2jg473991  167763266     florida     usa  22 hours left

# %%
# 2. print the size and shape of the datset
data.size
# Out:
# 2301

# %%
data.shape
# Out:
# (177, 13)

# %%
# 3. find the mean price for each brand using pandas function.

mean = data.groupby("brand")["price"].mean()
mean
# Out:
# brand
# bmw              37566.666667
# buick            20017.500000
# cadillac         28851.333333
# chevrolet        24665.266667
# chrysler         18332.307692
# dodge             8581.600000
# ford             14645.327586
# gmc              12711.176471
# infiniti         18500.000000
# jeep             17955.555556
# kia              11333.333333
# mercedes-benz    16600.000000
# toyota            6300.000000
# Name: price, dtype: float64

# %%
# 4. Count the car having Black color

cars = (data["color"] == "black").count()
cars
# Out:
# 177

# %%
# 5. Find which Brand have maximum car in year 2017

d = data[data["year"] == 2017]
d

car = d.groupby('brand')['model'].count()

brand = car.idxmax()
brand
# Out:
# 'ford'

# %%
# 6. Create a line chart which shows proportion for each car brand.

cars = data['brand'].unique()
num_car = []
for brand in cars:
    num = len(data[data['brand']==brand])
    num_car.append(num)
print(num_car)
fig = plt.figure(figsize =(10, 7))
plt.pie(num_car, labels = cars)
 
# show plot
plt.show()
# Out:
# [1, 58, 25, 30, 17, 13, 3, 6, 1, 2, 9, 6, 6]

# %%
# 7. Print the statistical information of the data frame

data.describe()
# Out:
#        Unnamed: 0         price         year        mileage           lot
# count  177.000000    177.000000   177.000000     177.000000  1.770000e+02
# mean    88.000000  17121.751412  2016.310734   46854.932203  1.676768e+08
# std     51.239633  11060.554802     4.084275   37352.978107  6.342515e+05
# min      0.000000      0.000000  1973.000000    2430.000000  1.593488e+08
# 25%     44.000000   7300.000000  2016.000000   28972.000000  1.676565e+08
# 50%     88.000000  15110.000000  2017.000000   35714.000000  1.677554e+08
# 75%    132.000000  23505.000000  2018.000000   48086.000000  1.677637e+08
# max    176.000000  55000.000000  2020.000000  274117.000000  1.678025e+08

# %%
# 8. Remove all the duplicate values from the data frame

d = data.duplicated().sum()
d
# Out:
# 0

# %%
# 9. Count the null values in the database and replace with median value.

n = data.isnull().sum()
n
# Out:
# Unnamed: 0      0
# price           0
# brand           0
# model           0
# year            0
# title_status    0
# mileage         0
# color           0
# vin             0
# lot             0
# state           0
# country         0
# condition       0
# dtype: int64
