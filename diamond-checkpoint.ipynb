# %%
# diamonds data set

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# 1. Load data set using pandas function and print last 5 records.

data = pd.read_csv("diamonds.csv")
data
# Out:
#      carat      cut color clarity  depth  table  price     x     y     z
# 0     0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1     0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2     0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3     0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4     0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ..     ...      ...   ...     ...    ...    ...    ...   ...   ...   ...
# 194   0.70  Premium     E     SI1   61.2   57.0   2777  5.73  5.68  3.49
# 195   0.70  Premium     E     SI1   62.7   59.0   2777  5.67  5.63  3.54
# 196   0.70  Premium     E     SI1   61.0   57.0   2777  5.73  5.68  3.48
# 197   0.70  Premium     E     SI1   61.0   58.0   2777  5.78  5.72  3.51
# 198   0.70    Ideal     E     SI1   61.4   57.0   2777  5.76  5.70  3.52
#
# [199 rows x 10 columns]

# %%
data.tail(5)
# Out:
#      carat      cut color clarity  depth  table  price     x     y     z
# 194    0.7  Premium     E     SI1   61.2   57.0   2777  5.73  5.68  3.49
# 195    0.7  Premium     E     SI1   62.7   59.0   2777  5.67  5.63  3.54
# 196    0.7  Premium     E     SI1   61.0   57.0   2777  5.73  5.68  3.48
# 197    0.7  Premium     E     SI1   61.0   58.0   2777  5.78  5.72  3.51
# 198    0.7    Ideal     E     SI1   61.4   57.0   2777  5.76  5.70  3.52

# %%
# 2 Draw the bar chart of costliest and cheapest diamonds

dprice = data['price']
pmax = max(dprice)
pmin = min(dprice)
print(pmin,pmax)
# Out:
# 326 2777

# %%
sorted_data = data.sort_values('price', ascending=False)

top_diamonds = sorted_data.head(1)
bottom_diamonds = sorted_data.tail(1)

selected_data = pd.concat([top_diamonds, bottom_diamonds])

selected_data.plot(x='carat', y='price', kind='bar', figsize=(8, 6), grid=True)

plt.title('Costliest and Cheapest Diamonds')
plt.xlabel('Carat')
plt.ylabel('Price')

plt.show()

# %%
# 3 Draw the chart for Price vs Carat of Diamonds.

x = data["price"]
y = data["carat"]

plt.plot(x,y)

# %%
# 4 Print the record where either of dimension (x,y,z) is Zero.

zero_dim = data[(data['x']==0.0) | (data['y']==0.0) | (data['z']==0.0)]
zero_dim
# Out:
# Empty DataFrame
# Columns: [carat, cut, color, clarity, depth, table, price, x, y, z]
# Index: []

# %%
# 5. 5 Create a new data frame by multiplying x,y,z.


data['xyz']=data['x']*data['y']*data['z']
data
# Out:
#      carat      cut color clarity  depth  table  price     x     y     z  \
# 0     0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1     0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2     0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3     0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4     0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ..     ...      ...   ...     ...    ...    ...    ...   ...   ...   ...
# 194   0.70  Premium     E     SI1   61.2   57.0   2777  5.73  5.68  3.49
# 195   0.70  Premium     E     SI1   62.7   59.0   2777  5.67  5.63  3.54
# 196   0.70  Premium     E     SI1   61.0   57.0   2777  5.73  5.68  3.48
# 197   0.70  Premium     E     SI1   61.0   58.0   2777  5.78  5.72  3.51
# 198   0.70    Ideal     E     SI1   61.4   57.0   2777  5.76  5.70  3.52
#
#             xyz
# 0     38.202030
# 1     34.505856
# 2     38.076885
# 3     46.724580
# ...

# %%
# 6 Drop all the dimension.(X,Y,Z).
drop_dimdf = data.drop(['x','y','z'],axis=1)
drop_dimdf
# Out:
#      carat      cut color clarity  depth  table  price         xyz
# 0     0.23    Ideal     E     SI2   61.5   55.0    326   38.202030
# 1     0.21  Premium     E     SI1   59.8   61.0    326   34.505856
# 2     0.23     Good     E     VS1   56.9   65.0    327   38.076885
# 3     0.29  Premium     I     VS2   62.4   58.0    334   46.724580
# 4     0.31     Good     J     SI2   63.3   58.0    335   51.917250
# ..     ...      ...   ...     ...    ...    ...    ...         ...
# 194   0.70  Premium     E     SI1   61.2   57.0   2777  113.586936
# 195   0.70  Premium     E     SI1   62.7   59.0   2777  113.004234
# 196   0.70  Premium     E     SI1   61.0   57.0   2777  113.261472
# 197   0.70  Premium     E     SI1   61.0   58.0   2777  116.046216
# 198   0.70    Ideal     E     SI1   61.4   57.0   2777  115.568640
#
# [199 rows x 8 columns]

# %%
# 7 Print all the Statistical information of the data frame.

data.describe()
# Out:
#             carat       depth       table        price           x  \
# count  199.000000  199.000000  199.000000   199.000000  199.000000
# mean     0.524020   61.629146   57.719598  1712.035176    5.047588
# std      0.237057    1.613471    2.355365  1166.046417    0.834121
# min      0.200000   55.100000   53.000000   326.000000    3.790000
# 25%      0.290000   60.800000   56.000000   404.000000    4.225000
# 50%      0.700000   61.700000   57.000000  2760.000000    5.560000
# 75%      0.720000   62.600000   59.000000  2768.000000    5.790000
# max      1.170000   66.300000   69.000000  2777.000000    6.830000
#
#                 y           z
# count  199.000000  199.000000
# mean     5.055075    3.112462
# std      0.823563    0.512692
# min      3.750000    2.270000
# 25%      4.250000    2.615000
# 50%      5.580000    3.380000
# 75%      5.780000    3.560000
# max      6.900000    4.130000

# %%
# 8 Remove all the duplicate values from the data frame

data.duplicated().count()

d = data.drop_duplicates()
d
# Out:
#      carat      cut color clarity  depth  table  price     x     y     z
# 0     0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1     0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2     0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3     0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4     0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ..     ...      ...   ...     ...    ...    ...    ...   ...   ...   ...
# 194   0.70  Premium     E     SI1   61.2   57.0   2777  5.73  5.68  3.49
# 195   0.70  Premium     E     SI1   62.7   59.0   2777  5.67  5.63  3.54
# 196   0.70  Premium     E     SI1   61.0   57.0   2777  5.73  5.68  3.48
# 197   0.70  Premium     E     SI1   61.0   58.0   2777  5.78  5.72  3.51
# 198   0.70    Ideal     E     SI1   61.4   57.0   2777  5.76  5.70  3.52
#
# [199 rows x 10 columns]

# %%
# 9 Count the null values in the database and replace with mean value.

n = data.isnull().sum()
n
# Out:
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# price      0
# x          0
# y          0
# z          0
# dtype: int64
