# %%
# iris data paper solve

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# 1.load data set using pandas function and  print first four record.

data = pd.read_csv("iris.csv")
data
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
data.head(4)
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa

# %%
# 2.print information of data set.

data.info
# Out:
# <bound method DataFrame.info of      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]>

# %%
# 3. Count the values of each class of species

co = data["variety"].value_counts()
co
# Out:
# Setosa        50
# Versicolor    50
# Virginica     50
# Name: variety, dtype: int64

# %%
# 4. Draw a line chart for sepal length and sepal width

x = data["sepal.length"]
y = data["sepal.width"]

plt.plot(x,y)

# %%
# 5. print shape and size of the data frame

data.size
# Out:
# 750

# %%
data.shape
# Out:
# (150, 5)

# %%
# 6. print all the column header of the data frame.

c = data.columns
c
# Out:
# Index(['sepal.length', 'sepal.width', 'petal.length', 'petal.width',
#        'variety'],
#       dtype='object')

# %%
# 7 .filter the record from index no 80 to 100.

f = data.iloc[80:101]
f
# Out:
#      sepal.length  sepal.width  petal.length  petal.width     variety
# 80            5.5          2.4           3.8          1.1  Versicolor
# 81            5.5          2.4           3.7          1.0  Versicolor
# 82            5.8          2.7           3.9          1.2  Versicolor
# 83            6.0          2.7           5.1          1.6  Versicolor
# 84            5.4          3.0           4.5          1.5  Versicolor
# 85            6.0          3.4           4.5          1.6  Versicolor
# 86            6.7          3.1           4.7          1.5  Versicolor
# 87            6.3          2.3           4.4          1.3  Versicolor
# 88            5.6          3.0           4.1          1.3  Versicolor
# 89            5.5          2.5           4.0          1.3  Versicolor
# 90            5.5          2.6           4.4          1.2  Versicolor
# 91            6.1          3.0           4.6          1.4  Versicolor
# ...

# %%
# 8. remove all the duplicate value from the data frame.

d = data.drop_duplicates()
d
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [149 rows x 5 columns]

# %%
# 9. count the null values in dataframe and replace with median value.

n = data.isnull().sum()
n
# Out:
# sepal.length    0
# sepal.width     0
# petal.length    0
# petal.width     0
# variety         0
# dtype: int64
